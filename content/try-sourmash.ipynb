# %%
# %pip install sourmash

# %%
# %run sourmash compare data/*.fa.sig -k 21 -o cmp
# Out:
# == This is sourmash version 4.8.11. ==
# == Please cite Irber et. al (2024), doi:10.21105/joss.06830. ==
#
# loaded 3 signatures total.
# 0-CP001941.1 Acid...	[1. 0. 0.]
# 1-NC_009665.1 She...	[0.    1.    0.395]
# 2-NC_011663.1 She...	[0.    0.395 1.   ]
# min similarity in matrix: 0.000
# saving labels to: cmp.labels.txt
# saving comparison matrix to: cmp

# %%
# %run sourmash plot cmp
# Out:
# Matplotlib is building the font cache; this may take a moment.
# loading comparison matrix from cmp...
# ...got 3 x 3 matrix.
# loading labels from text file 'cmp.labels.txt'
# saving histogram of matrix values => cmp.hist.png
# wrote dendrogram to: cmp.dendro.png
# wrote numpy distance matrix to: cmp.matrix.png
# 0	CP001941.1 Aciduliprofundum boonei T469, complete genome
# 1	NC_009665.1 Shewanella baltica OS185, complete genome
# 2	NC_011663.1 Shewanella baltica OS223, complete genome

# %%
from IPython.display import Image
Image(filename='cmp.matrix.png', width=500)
